# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('energydata_complete.csv')

# %%
df.shape
# Out:
# (19735, 29)

# %%
df.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %%
renamed_columns = {'T2': 'Temperature Inside', 'T6': 'Temperature Outside'}

# %%
df = df.rename(columns=renamed_columns)

# %%
df.head()
# Out:
#                   date  Appliances  lights     T1       RH_1  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333
#
#    Temperature Inside       RH_2     T3       RH_3         T4  ...         T9  \
# 0                19.2  44.790000  19.79  44.730000  19.000000  ...  17.033333
# 1                19.2  44.722500  19.79  44.790000  19.000000  ...  17.066667
# 2                19.2  44.626667  19.79  44.933333  18.926667  ...  17.000000
# 3                19.2  44.590000  19.79  45.000000  18.890000  ...  17.000000
# 4                19.2  44.530000  19.79  45.000000  18.890000  ...  17.000000
#
#     RH_9     T_out  Press_mm_hg  RH_out  Windspeed  Visibility  Tdewpoint  \
# ...

# %%
reg_df = df[['Temperature Inside', 'Temperature Outside']].sample(100, random_state=2)

# %%
#regression plot
sns.regplot(x='Temperature Inside', y='Temperature Outside', data=reg_df)
# Out:
# <Axes: xlabel='Temperature Inside', ylabel='Temperature Outside'>

# %%
#preprocessing
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
df = df.drop(columns=['date'])

# %%
normalized_df = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)

# %%
df.head()
# Out:
#    Appliances  lights     T1       RH_1  Temperature Inside       RH_2     T3  \
# 0          60      30  19.89  47.596667                19.2  44.790000  19.79
# 1          60      30  19.89  46.693333                19.2  44.722500  19.79
# 2          50      30  19.89  46.300000                19.2  44.626667  19.79
# 3          50      40  19.89  46.066667                19.2  44.590000  19.79
# 4          60      40  19.89  46.333333                19.2  44.530000  19.79
#
#         RH_3         T4       RH_4  ...         T9   RH_9     T_out  \
# 0  44.730000  19.000000  45.566667  ...  17.033333  45.53  6.600000
# 1  44.790000  19.000000  45.992500  ...  17.066667  45.56  6.483333
# 2  44.933333  18.926667  45.890000  ...  17.000000  45.50  6.366667
# 3  45.000000  18.890000  45.723333  ...  17.000000  45.40  6.250000
# 4  45.000000  18.890000  45.530000  ...  17.000000  45.40  6.133333
#
#    Press_mm_hg  RH_out  Windspeed  Visibility  Tdewpoint        rv1        rv2
# ...

# %%
normalized_df.head()
# Out:
#    Appliances    lights       T1      RH_1  Temperature Inside      RH_2  \
# 0    0.046729  0.428571  0.32735  0.566187            0.225345  0.684038
# 1    0.046729  0.428571  0.32735  0.541326            0.225345  0.682140
# 2    0.037383  0.428571  0.32735  0.530502            0.225345  0.679445
# 3    0.037383  0.571429  0.32735  0.524080            0.225345  0.678414
# 4    0.046729  0.571429  0.32735  0.531419            0.225345  0.676727
#
#          T3      RH_3        T4      RH_4  ...        T9      RH_9     T_out  \
# 0  0.215188  0.746066  0.351351  0.764262  ...  0.223032  0.677290  0.372990
# 1  0.215188  0.748871  0.351351  0.782437  ...  0.226500  0.678532  0.369239
# 2  0.215188  0.755569  0.344745  0.778062  ...  0.219563  0.676049  0.365488
# 3  0.215188  0.758685  0.341441  0.770949  ...  0.219563  0.671909  0.361736
# 4  0.215188  0.758685  0.341441  0.762697  ...  0.219563  0.671909  0.357985
#
# ...

# %%
features_df = normalized_df[['Temperature Inside']]

# %%
features_df.head()
# Out:
#    Temperature Inside
# 0            0.225345
# 1            0.225345
# 2            0.225345
# 3            0.225345
# 4            0.225345

# %%
target = normalized_df['Temperature Outside']

# %%
target.head()
# Out:
# 0    0.381070
# 1    0.375443
# 2    0.367487
# 3    0.363800
# 4    0.361859
# Name: Temperature Outside, dtype: float64

# %%
#modelling
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(features_df, target, test_size = 0.3, random_state = 1)

# %%
from sklearn.linear_model import LinearRegression
linear_model = LinearRegression()

# %%
linear_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
pred_values = linear_model.predict(x_test)

# %%
pred_values
# Out:
# array([0.27457749, 0.44635267, 0.59807124, ..., 0.35286298, 0.45206773,
#        0.39168223])

# %%
from sklearn.metrics import r2_score

# %%
r2_score = r2_score(y_test, pred_values)

# %%
round(r2_score, 3)
# Out:
# 0.646
